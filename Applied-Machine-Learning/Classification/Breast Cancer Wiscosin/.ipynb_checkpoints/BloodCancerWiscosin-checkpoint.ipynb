# %%
# %matplotlib inline    
# Line magic command will make plot outputs appear and be stored within the notebook.
import matplotlib.pyplot as plt   # matplotlib's plotting framework

import numpy as np    # fundamental package for scientific computing
import pandas as pd   # Python Data Analysis Library
import seaborn as sns # library for making statistical graphics in Python
import os             # operating system dependent functionality, file descriptor..

# %% [markdown]
# #  Read the Data
# - Read the data
# - Perform some basic structural cleaning to facilitate the work

# %%
# Let's check what data files are available.
PATH="./Data/"
os.listdir(PATH)
# Out:
# ['breast-cancer-wisconsin.data',
#  'breast-cancer-wisconsin.names',
#  'Index',
#  'unformatted-data',
#  'wdbc.data',
#  'wdbc.names',
#  'wpbc.data',
#  'wpbc.names']

# %%
BC_train_wdbc   = pd.read_csv( PATH + 'breast-cancer-wisconsin.data', header = None, na_values = ['?'] )
BC_train_wdbc.columns = [ 'SampleCodeNumber','ClumpThickness','UniformityofCellSize','UniformityofCellShape','MarginalAdhesion',
'SingleEpithelialCellSize','BareNuclei','BlandChromatin','NormalNucleoli','Mitoses','Class' ]
BC_train_wdbc.isna().sum()
# Out:
# SampleCodeNumber             0
# ClumpThickness               0
# UniformityofCellSize         0
# UniformityofCellShape        0
# MarginalAdhesion             0
# SingleEpithelialCellSize     0
# BareNuclei                  16
# BlandChromatin               0
# NormalNucleoli               0
# Mitoses                      0
# Class                        0
# dtype: int64

# %%
# Checking missing values
BC_train_wdbc[BC_train_wdbc['BareNuclei'].isnull()]
# Out:
#      SampleCodeNumber  ClumpThickness  UniformityofCellSize  \
# 23            1057013               8                     4
# 40            1096800               6                     6
# 139           1183246               1                     1
# 145           1184840               1                     1
# 158           1193683               1                     1
# 164           1197510               5                     1
# 235           1241232               3                     1
# 249            169356               3                     1
# 275            432809               3                     1
# 292            563649               8                     8
# 294            606140               1                     1
# 297             61634               5                     4
# 315            704168               4                     6
# 321            733639               3                     1
# 411           1238464               1                     1
# ...

# %%
BC_train_wdbc.loc[30:43][['BareNuclei','SingleEpithelialCellSize']]
# Out:
#     BareNuclei  SingleEpithelialCellSize
# 30         1.0                         1
# 31         1.0                         2
# 32         5.0                         8
# 33         1.0                         2
# 34         1.0                         2
# 35         1.0                         2
# 36         1.0                         6
# 37         1.0                         1
# 38        10.0                         2
# 39         7.0                         6
# 40         NaN                         6
# 41         3.0                         3
# 42        10.0                         8
# 43         1.0                        10

# %%
BC_train_wdbc.fillna(method='ffill', inplace = True)
BC_train_wdbc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 699 entries, 0 to 698
# Data columns (total 11 columns):
# SampleCodeNumber            699 non-null int64
# ClumpThickness              699 non-null int64
# UniformityofCellSize        699 non-null int64
# UniformityofCellShape       699 non-null int64
# MarginalAdhesion            699 non-null int64
# SingleEpithelialCellSize    699 non-null int64
# BareNuclei                  699 non-null float64
# BlandChromatin              699 non-null int64
# NormalNucleoli              699 non-null int64
# Mitoses                     699 non-null int64
# Class                       699 non-null int64
# dtypes: float64(1), int64(10)
# memory usage: 60.1 KB

# %%
for col in ['ClumpThickness','UniformityofCellSize','UniformityofCellShape','MarginalAdhesion','SingleEpithelialCellSize','BareNuclei','BlandChromatin','NormalNucleoli','Mitoses']:
    BC_train_wdbc[col] = BC_train_wdbc[col].astype( 'int8' )

# %%
#BC_train_wdbc['Class'] = BC_train_wdbc['Class'].astype( 'category' )
BC_train_wdbc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 699 entries, 0 to 698
# Data columns (total 11 columns):
# SampleCodeNumber            699 non-null int64
# ClumpThickness              699 non-null int8
# UniformityofCellSize        699 non-null int8
# UniformityofCellShape       699 non-null int8
# MarginalAdhesion            699 non-null int8
# SingleEpithelialCellSize    699 non-null int8
# BareNuclei                  699 non-null int8
# BlandChromatin              699 non-null int8
# NormalNucleoli              699 non-null int8
# Mitoses                     699 non-null int8
# Class                       699 non-null int64
# dtypes: int64(2), int8(9)
# memory usage: 17.1 KB

# %%
BC_train_wdbc.describe()
# Out:
#        SampleCodeNumber  ClumpThickness  UniformityofCellSize  \
# count      6.990000e+02      699.000000            699.000000
# mean       1.071704e+06        4.417740              3.134478
# std        6.170957e+05        2.815741              3.051459
# min        6.163400e+04        1.000000              1.000000
# 25%        8.706885e+05        2.000000              1.000000
# 50%        1.171710e+06        4.000000              1.000000
# 75%        1.238298e+06        6.000000              5.000000
# max        1.345435e+07       10.000000             10.000000
#
#        UniformityofCellShape  MarginalAdhesion  SingleEpithelialCellSize  \
# count             699.000000        699.000000                699.000000
# mean                3.207439          2.806867                  3.216023
# std                 2.971913          2.855379                  2.214300
# min                 1.000000          1.000000                  1.000000
# ...

# %%
BC_train_wdbc.corr()
# Out:
#                           SampleCodeNumber  ClumpThickness  \
# SampleCodeNumber                  1.000000       -0.055308
# ClumpThickness                   -0.055308        1.000000
# UniformityofCellSize             -0.041603        0.644913
# UniformityofCellShape            -0.041576        0.654589
# MarginalAdhesion                 -0.064878        0.486356
# SingleEpithelialCellSize         -0.045528        0.521816
# BareNuclei                       -0.099136        0.583571
# BlandChromatin                   -0.060051        0.558428
# NormalNucleoli                   -0.052072        0.535835
# Mitoses                          -0.034901        0.350034
# Class                            -0.080226        0.716001
#
#                           UniformityofCellSize  UniformityofCellShape  \
# SampleCodeNumber                     -0.041603              -0.041576
# ClumpThickness                        0.644913               0.654589
# ...

# %%
BC_train_wdbc['SampleCodeNumber'].unique().size
# Out:
# 645

# %% [markdown]
# So some duplicate numbers are there in Sample Code Number, so wee cant set it as index.
# BC_train_wdbc = pd.get_dummies( BC_train_wdbc)

# %%
BC_train_wdbc.head(20)
# Out:
#     SampleCodeNumber  ClumpThickness  UniformityofCellSize  \
# 0            1000025               5                     1
# 1            1002945               5                     4
# 2            1015425               3                     1
# 3            1016277               6                     8
# 4            1017023               4                     1
# 5            1017122               8                    10
# 6            1018099               1                     1
# 7            1018561               2                     1
# 8            1033078               2                     1
# 9            1033078               4                     2
# 10           1035283               1                     1
# 11           1036172               2                     1
# 12           1041801               5                     3
# 13           1043999               1                     1
# 14           1044572               8                     7
# ...

# %%
BC_train_wdbc['Class'].unique()
BC_train_wdbc['Class'] = BC_train_wdbc['Class'].map({2: 0, 4:1})
# BC_train_wdbc['Class'] = (BC_train_wdbc['Class'] / 4).astype( 'int' )

# %%
BC_train_wdbc.head(20)
# Out:
#     SampleCodeNumber  ClumpThickness  UniformityofCellSize  \
# 0            1000025               5                     1
# 1            1002945               5                     4
# 2            1015425               3                     1
# 3            1016277               6                     8
# 4            1017023               4                     1
# 5            1017122               8                    10
# 6            1018099               1                     1
# 7            1018561               2                     1
# 8            1033078               2                     1
# 9            1033078               4                     2
# 10           1035283               1                     1
# 11           1036172               2                     1
# 12           1041801               5                     3
# 13           1043999               1                     1
# 14           1044572               8                     7
# ...

# %%
BC_train_wdbc = pd.get_dummies( BC_train_wdbc )
BC_train_wdbc.head()
# Out:
#    SampleCodeNumber  ClumpThickness  UniformityofCellSize  \
# 0           1000025               5                     1
# 1           1002945               5                     4
# 2           1015425               3                     1
# 3           1016277               6                     8
# 4           1017023               4                     1
#
#    UniformityofCellShape  MarginalAdhesion  SingleEpithelialCellSize  \
# 0                      1                 1                         2
# 1                      4                 5                         7
# 2                      1                 1                         2
# 3                      8                 1                         3
# 4                      1                 3                         2
#
#    BareNuclei  BlandChromatin  NormalNucleoli  Mitoses  Class
# 0           1               3               1        1      0
# 1          10               3               2        1      0
# ...

# %%
from sklearn.ensemble import BaggingClassifier
from sklearn.metrics import accuracy_score
array = BC_train_wdbc.values
X = array[:,0:10]
Y = array[:,10]

# %%
from sklearn import model_selection
from sklearn.tree import DecisionTreeClassifier
seed = 7
kfold = model_selection.KFold(n_splits=10, random_state=seed)
cart = DecisionTreeClassifier()
num_trees = 100
model = BaggingClassifier(base_estimator=cart, n_estimators=num_trees, random_state=seed)
pred = model_selection.cross_val_predict(model, X, Y, cv=kfold)
print ("Test Accuracy  :: ", accuracy_score(Y, pred))
print ("Test ROC AUC  :: ", roc_auc_score(Y, pred))

fpr, tpr, _ = roc_curve(Y, pred)

plt.clf()
plt.plot(fpr, tpr)
plt.xlabel('FPR')
plt.ylabel('TPR')
plt.title('ROC curve')
plt.show()
# Out:
# Test Accuracy  ::  0.9570815450643777
# Test ROC AUC  ::  0.9525041221982642

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_curve, roc_auc_score
seed = 7
num_trees = 100
max_features = 3
kfold = model_selection.KFold(n_splits=10, random_state=seed)

model = RandomForestClassifier(n_estimators=num_trees, max_features=max_features)
pred = model_selection.cross_val_predict(model, X, Y, cv=kfold)

from sklearn.metrics import roc_curve, auc

print ("Test Accuracy  :: ", accuracy_score(Y, pred))
print ("Test ROC AUC  :: ", roc_auc_score(Y, pred))

fpr, tpr, _ = roc_curve(Y, pred)

plt.clf()
plt.plot(fpr, tpr)
plt.xlabel('FPR')
plt.ylabel('TPR')
plt.title('ROC curve')
plt.show()
# Out:
# Test Accuracy  ::  0.9656652360515021
# Test ROC AUC  ::  0.9629862834985233
